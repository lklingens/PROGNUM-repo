# %%
from astropy.io import fits
from matplotlib.pyplot import figure, show
import numpy as np

fig = figure(figsize=(12, 12)) # Create a figure.

# Messier 101
hdulist2 = fits.open('/Users/users/lklingens/PROGNUM-repo/Task8/Images/m101.fits')  # Open file.
data2 = hdulist2[0].data  # Get image data.

frame2 = fig.add_subplot(2,2,1)
frame2.imshow(data2)

# Centaurus A
hdulist3 = fits.open('/Users/users/lklingens/PROGNUM-repo/Task8/Images/cent_A.fits')  # Open file.
data3 = hdulist3[0].data  # Get image data.

frame3 = fig.add_subplot(2,2,2)
frame3.imshow(data3)

# Messier 32
hdulist5 = fits.open('/Users/users/lklingens/PROGNUM-repo/Task8/Images/m32_2.fits')  # Open file.
data5 = hdulist5[0].data  # Get image data.

frame5 = fig.add_subplot(2,2,3)
frame5.imshow(data5)

# Antennae Galaxies
hdulist6 = fits.open('/Users/users/lklingens/PROGNUM-repo/Task8/Images/antennae.fits')  # Open file.
data6 = hdulist6[0].data  # Get image data.

frame6 = fig.add_subplot(2,2,4)
frame6.imshow(data6)

fig2 = figure(figsize=(12, 12)) # Create a figure.

# Cigar galaxy
hdulist7 = fits.open('/Users/users/lklingens/PROGNUM-repo/Task8/Images/cigar.fits')  # Open file.
data7 = hdulist7[0].data  # Get image data.

frame7 = fig2.add_subplot(2,2,1)
frame7.imshow(data7)

# Bode's Galaxy
hdulist8 = fits.open('/Users/users/lklingens/PROGNUM-repo/Task8/Images/bode.fits')  # Open file.
data8 = hdulist8[0].data  # Get image data.

frame8 = fig2.add_subplot(2,2,2)
frame8.imshow(data8)

# Fireworks galaxy
hdulist9 = fits.open('/Users/users/lklingens/PROGNUM-repo/Task8/Images/fireworks.fits')  # Open file.
data9 = hdulist9[0].data  # Get image data.

frame9 = fig2.add_subplot(2,2,3)
frame9.imshow(data9)

# Black Eye galaxy
hdulist10 = fits.open('/Users/users/lklingens/PROGNUM-repo/Task8/Images/black_eye.fits')  # Open file.
data10 = hdulist10[0].data  # Get image data.

frame10 = fig2.add_subplot(2,2,4)
frame10.imshow(data10)

show()

# %%
from astropy.io import fits
import numpy as np
from astropy.table import QTable

# Black Eye galaxy
hdulist10 = fits.open('/Users/users/lklingens/PROGNUM-repo/Task8/Images/black_eye.fits')  # Open file.
hdulist10.info()

hdr = hdulist10[0].header
print(hdr)
data10 = hdulist10[0].data  # Get image data.

date = hdr['DATE-OBS']  # This tells you the exact day/time the galaxy was photographed
exp = hdr['EXPOSURE']  # This tells you how long the telescope shutter was open in minutes
tel = hdr['TELESCOP']  # The name of the famous telescope
RA = hdr['OBJCTRA']  # Real time RA
DEC = hdr['OBJCTDEC']  # Real time dec

print(f"\n {date}")
print(exp)
print(tel)
print(RA)
print(DEC)
# Out:
# Filename: /Users/users/lklingens/PROGNUM-repo/Task8/Images/black_eye.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     161   (891, 893)   int16
#   1  xp.mask       1 TableHDU        25   1600R x 4C   [F6.2, F6.2, F6.2, F6.2]
# ...
