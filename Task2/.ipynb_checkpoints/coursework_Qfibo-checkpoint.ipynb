# %%
condition = True

N = int(input("Enter your number for N:"))
M = int(input("Enter your number for M:"))

def fibo(N, M):
    previous = 0
    new = 1
    numbers = []
    while condition == True:
        if previous < N and previous % M == 0:
            numbers.append(previous)
        elif new >= 100000:
            break
        following = previous + new 
        previous = new
        new = following
    return numbers

print(f"The Fibonacci numbers that are less than N and can be divided by M are: {fibo(N,M)}")
# Out:
# Enter your number for N: 100
# Enter your number for M: 7
# The Fibonacci numbers that are less than N and can be divided by M are: [0, 21]

# %%
condition = True
previous = 1
new = 2

while condition == True:
    following = previous + new 
    previous = new
    new = following
    if new >= 1000:
        break

print(new)
# Out:
# 1597
