# %%
n = 0
prev_seq = 1
seq = 1

while n <= 10:
    print(n, prev_seq, seq)
    n += 1

print("Final values:", n, prev_seq, seq)
# Out:
# 0 1 1
# 1 1 2
# 2 2 3
# 3 3 5
# 4 5 8
# 5 8 13
# 6 13 21
# 7 21 34
# 8 34 55
# 9 55 89
# 10 89 144
# Final values: 11 144 233
